# %% [markdown]
# # Test-7 — English → Odia Transformer
# This notebook is the presentation-friendly control panel for the full project. The implementation lives in `src/` and the reproducible scripts live in `scripts/`.

# %%
# !pip install -r requirements.txt

# %%
# !python scripts/download_data.py
# !python scripts/prepare_data.py
# !python scripts/train_tokenizers.py

# %%
# !python scripts/run_tests.py

# %%
# !python scripts/train.py

# %%
# !python scripts/evaluate.py

# %% [markdown]
# ## Required discussion points
# - Teacher forcing and PAD-ignored cross entropy
# - Strict causal mask and leakage test
# - Separate BPE tokenizers for English/Odia
# - Odia Unicode normalization and morphology
# - BLEU interpretation
# - Long-sentence limitation of a compact from-scratch Transformer
